# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
plt.style.use('ggplot')
import seaborn as sns

# %%
#so all DataFrame data is displayed
pd.set_option('display.max_columns',None)
pd.set_option('display.min_rows',0)
pd.set_option('display.max_rows',100)

# %%
housing = pd.read_csv("./data/Ames_Housing_Price_Data.csv", index_col=0)
realestate = pd.read_csv('./data/Ames_Real_Estate_Data.csv', index_col=0)
# Out:
# /Users/isa.adls/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (36,40,81,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### Extra Trees on all Features

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ### Getting Lat - LONG

# %%
#making index a column 
realestate['MapRefNo'] = realestate.index

# creating a new dataframe with only necessary columns 
realestate1 = realestate[['MapRefNo', 'GeoRefNo', 'Prop_Addr', 'Neighborhood', 'ClassPr_S', 'SchD_S', 'TxD_S']]

#renamed realestate MapRefNo to PID to Merge on PID 
realestate1.rename(columns = {'MapRefNo':'PID'}, inplace = True) 

#Merging Dataframes on PID
clean_df = pd.merge(housing, realestate1, on = 'PID', how='left')
# Out:
# /Users/isa.adls/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#dropping duplicates 
clean_df = clean_df.drop_duplicates(subset = ['PID'])
clean_df.shape #checking shape
# Out:
# (2579, 87)

# %%
# Function to get Latitude and Longitude

from geopy.geocoders import Nominatim
# location = geolocator.geocode("2400 SE 16TH ST AMES, IA")

def get_lat_log(address):
    geolocator = Nominatim(user_agent="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36")
    geocode = lambda query: geolocator.geocode("%s, AMES IA" % query)
    location = geocode(address)
    
    if location == None:
        return None 
    
    return (location.latitude, location.longitude)

# %%
# Function to get distance from schools
from geopy.distance import geodesic

def get_school_dist(lat_log, school_lat_log):
    """ Get School Distance
    :lat_log - tuple, address lat and log
    :school_lst_log -tuple, school lat and log
    Return: distance between both addresses
    """
    return(geodesic(lat_log, school_lat_log).miles)

# %%
from time import sleep


addresses = clean_df["Prop_Addr"]

total_addresses = len(addresses)
count = 0
none_count_hs = 0
none_count_c = 0

high_school = "Ames High School 1921 Ames High Drive Ames, IA 50010"
hs_lat_log = get_lat_log(high_school)

college = "100 Enrollment Services Ctr"
c_lat_log = get_lat_log(college)

address_lat_log = []
highschool_dist = []
college_dist = []

for address in addresses:
    sleep(.25)
    lat_log = get_lat_log(address)
    address_lat_log.append(lat_log)
    
    dist_hs = get_school_dist(lat_log, hs_lat_log)
    if dist_hs is None:
        dist_hs = 0
        non_count_hs += 1
    highschool_dist.append(dist_hs) 
    
    sleep(.25)
    dist_c = get_school_dist(lat_log, c_lat_log)
    if dist_c is None:
        dist_c = 0
        non_count_c += 1
    college_dist.append(dist_c)
    
    
    count += 1
    print(f"On address {count} out of {total_addresses}")
    print(f"Got None: High School: {none_count_hs} college: {none_count_c}")

print("Done!")
# Out:
# On address 1 out of 2579
# Got None: High School: 0 college: 0
# On address 2 out of 2579
# Got None: High School: 0 college: 0
# On address 3 out of 2579
# Got None: High School: 0 college: 0
# On address 4 out of 2579
# Got None: High School: 0 college: 0
# On address 5 out of 2579
# Got None: High School: 0 college: 0
# On address 6 out of 2579
# Got None: High School: 0 college: 0
# On address 7 out of 2579
# Got None: High School: 0 college: 0
# On address 8 out of 2579
# Got None: High School: 0 college: 0
# On address 9 out of 2579
# Got None: High School: 0 college: 0
# On address 10 out of 2579
# Got None: High School: 0 college: 0
# On address 11 out of 2579
# Got None: High School: 0 college: 0
# On address 12 out of 2579
# Got None: High School: 0 college: 0
# On address 13 out of 2579
# Got None: High School: 0 college: 0
# On address 14 out of 2579
# Got None: High School: 0 college: 0
# On address 15 out of 2579
# Got None: High School: 0 college: 0
# On address 16 out of 2579
# Got None: High School: 0 college: 0
# On address 17 out of 2579
# Got None: High School: 0 college: 0
# On address 18 out of 2579
# Got None: High School: 0 college: 0
# On address 19 out of 2579
# Got None: High School: 0 college: 0
# On address 20 out of 2579
# Got None: High School: 0 college: 0
# On address 21 out of 2579
# Got None: High School: 0 college: 0
# On address 22 out of 2579
# Got None: High School: 0 college: 0
# On address 23 out of 2579
# Got None: High School: 0 college: 0
# On address 24 out of 2579
# Got None: High School: 0 college: 0
# On address 25 out of 2579
# Got None: High School: 0 college: 0
# On address 26 out of 2579
# Got None: High School: 0 college: 0
# On address 27 out of 2579
# Got None: High School: 0 college: 0
# On address 28 out of 2579
# Got None: High School: 0 college: 0
# On address 29 out of 2579
# Got None: High School: 0 college: 0
# On address 30 out of 2579
# Got None: High School: 0 college: 0
# On address 31 out of 2579
# Got None: High School: 0 college: 0
# On address 32 out of 2579
# Got None: High School: 0 college: 0
# On address 33 out of 2579
# Got None: High School: 0 college: 0
# On address 34 out of 2579
# Got None: High School: 0 college: 0
# On address 35 out of 2579
# Got None: High School: 0 college: 0
# On address 36 out of 2579
# Got None: High School: 0 college: 0
# On address 37 out of 2579
# Got None: High School: 0 college: 0
# On address 38 out of 2579
# Got None: High School: 0 college: 0
# On address 39 out of 2579
# Got None: High School: 0 college: 0
# On address 40 out of 2579
# Got None: High School: 0 college: 0
# On address 41 out of 2579
# Got None: High School: 0 college: 0
# On address 42 out of 2579
# Got None: High School: 0 college: 0
# On address 43 out of 2579
# Got None: High School: 0 college: 0
# On address 44 out of 2579
# Got None: High School: 0 college: 0
# On address 45 out of 2579
# Got None: High School: 0 college: 0
# On address 46 out of 2579
# Got None: High School: 0 college: 0
# On address 47 out of 2579
# Got None: High School: 0 college: 0
# On address 48 out of 2579
# Got None: High School: 0 college: 0
# On address 49 out of 2579
# Got None: High School: 0 college: 0
# On address 50 out of 2579
# Got None: High School: 0 college: 0
# On address 51 out of 2579
# Got None: High School: 0 college: 0
# On address 52 out of 2579
# Got None: High School: 0 college: 0
# On address 53 out of 2579
# Got None: High School: 0 college: 0
# On address 54 out of 2579
# Got None: High School: 0 college: 0
# On address 55 out of 2579
# Got None: High School: 0 college: 0
# On address 56 out of 2579
# Got None: High School: 0 college: 0
# On address 57 out of 2579
# Got None: High School: 0 college: 0
# On address 58 out of 2579
# Got None: High School: 0 college: 0
# On address 59 out of 2579
# Got None: High School: 0 college: 0
# On address 60 out of 2579
# Got None: High School: 0 college: 0
# On address 61 out of 2579
# Got None: High School: 0 college: 0
# On address 62 out of 2579
# Got None: High School: 0 college: 0
# On address 63 out of 2579
# Got None: High School: 0 college: 0
# On address 64 out of 2579
# Got None: High School: 0 college: 0
# On address 65 out of 2579
# Got None: High School: 0 college: 0
# On address 66 out of 2579
# Got None: High School: 0 college: 0
# On address 67 out of 2579
# Got None: High School: 0 college: 0
# On address 68 out of 2579
# Got None: High School: 0 college: 0
# On address 69 out of 2579
# Got None: High School: 0 college: 0
# On address 70 out of 2579
# Got None: High School: 0 college: 0
# On address 71 out of 2579
# Got None: High School: 0 college: 0
# On address 72 out of 2579
# Got None: High School: 0 college: 0
# On address 73 out of 2579
# Got None: High School: 0 college: 0
# On address 74 out of 2579
# Got None: High School: 0 college: 0
# On address 75 out of 2579
# Got None: High School: 0 college: 0
# On address 76 out of 2579
# Got None: High School: 0 college: 0
# On address 77 out of 2579
# Got None: High School: 0 college: 0
# On address 78 out of 2579
# Got None: High School: 0 college: 0
# On address 79 out of 2579
# Got None: High School: 0 college: 0
# On address 80 out of 2579
# Got None: High School: 0 college: 0
# On address 81 out of 2579
# Got None: High School: 0 college: 0
# On address 82 out of 2579
# Got None: High School: 0 college: 0
# On address 83 out of 2579
# Got None: High School: 0 college: 0
# On address 84 out of 2579
# Got None: High School: 0 college: 0
# On address 85 out of 2579
# Got None: High School: 0 college: 0
# On address 86 out of 2579
# Got None: High School: 0 college: 0
# On address 87 out of 2579
# Got None: High School: 0 college: 0
# On address 88 out of 2579
# Got None: High School: 0 college: 0
# On address 89 out of 2579
# Got None: High School: 0 college: 0
# On address 90 out of 2579
# Got None: High School: 0 college: 0
# On address 91 out of 2579
# Got None: High School: 0 college: 0
# On address 92 out of 2579
# Got None: High School: 0 college: 0
# On address 93 out of 2579
# Got None: High School: 0 college: 0
# On address 94 out of 2579
# Got None: High School: 0 college: 0
# On address 95 out of 2579
# Got None: High School: 0 college: 0
# On address 96 out of 2579
# Got None: High School: 0 college: 0
# On address 97 out of 2579
# Got None: High School: 0 college: 0
# On address 98 out of 2579
# Got None: High School: 0 college: 0
# On address 99 out of 2579
# Got None: High School: 0 college: 0
# On address 100 out of 2579
# Got None: High School: 0 college: 0
# On address 101 out of 2579
# Got None: High School: 0 college: 0
# On address 102 out of 2579
# Got None: High School: 0 college: 0
# On address 103 out of 2579
# Got None: High School: 0 college: 0
# On address 104 out of 2579
# Got None: High School: 0 college: 0
# On address 105 out of 2579
# Got None: High School: 0 college: 0
# On address 106 out of 2579
# Got None: High School: 0 college: 0
# On address 107 out of 2579
# Got None: High School: 0 college: 0
# On address 108 out of 2579
# Got None: High School: 0 college: 0
# On address 109 out of 2579
# Got None: High School: 0 college: 0
# On address 110 out of 2579
# Got None: High School: 0 college: 0
# On address 111 out of 2579
# Got None: High School: 0 college: 0
# On address 112 out of 2579
# Got None: High School: 0 college: 0
# On address 113 out of 2579
# Got None: High School: 0 college: 0
# On address 114 out of 2579
# Got None: High School: 0 college: 0
# On address 115 out of 2579
# Got None: High School: 0 college: 0
# On address 116 out of 2579
# Got None: High School: 0 college: 0
# On address 117 out of 2579
# Got None: High School: 0 college: 0
# On address 118 out of 2579
# Got None: High School: 0 college: 0
# On address 119 out of 2579
# Got None: High School: 0 college: 0
# On address 120 out of 2579
# Got None: High School: 0 college: 0
# On address 121 out of 2579
# Got None: High School: 0 college: 0
# On address 122 out of 2579
# Got None: High School: 0 college: 0
# On address 123 out of 2579
# Got None: High School: 0 college: 0
# On address 124 out of 2579
# Got None: High School: 0 college: 0
# On address 125 out of 2579
# Got None: High School: 0 college: 0
# On address 126 out of 2579
# Got None: High School: 0 college: 0
# On address 127 out of 2579
# Got None: High School: 0 college: 0
# On address 128 out of 2579
# Got None: High School: 0 college: 0
# On address 129 out of 2579
# Got None: High School: 0 college: 0
# On address 130 out of 2579
# Got None: High School: 0 college: 0
# On address 131 out of 2579
# Got None: High School: 0 college: 0
# On address 132 out of 2579
# Got None: High School: 0 college: 0
# On address 133 out of 2579
# Got None: High School: 0 college: 0
# On address 134 out of 2579
# Got None: High School: 0 college: 0
# On address 135 out of 2579
# Got None: High School: 0 college: 0
# On address 136 out of 2579
# Got None: High School: 0 college: 0
# On address 137 out of 2579
# Got None: High School: 0 college: 0
# On address 138 out of 2579
# Got None: High School: 0 college: 0
# On address 139 out of 2579
# Got None: High School: 0 college: 0
# On address 140 out of 2579
# Got None: High School: 0 college: 0
# On address 141 out of 2579
# Got None: High School: 0 college: 0
# On address 142 out of 2579
# Got None: High School: 0 college: 0
# On address 143 out of 2579
# Got None: High School: 0 college: 0
# On address 144 out of 2579
# Got None: High School: 0 college: 0
# On address 145 out of 2579
# Got None: High School: 0 college: 0
# On address 146 out of 2579
# Got None: High School: 0 college: 0
# On address 147 out of 2579
# Got None: High School: 0 college: 0
# On address 148 out of 2579
# Got None: High School: 0 college: 0
# On address 149 out of 2579
# Got None: High School: 0 college: 0
# On address 150 out of 2579
# Got None: High School: 0 college: 0
# On address 151 out of 2579
# Got None: High School: 0 college: 0
# On address 152 out of 2579
# Got None: High School: 0 college: 0
# On address 153 out of 2579
# Got None: High School: 0 college: 0
# On address 154 out of 2579
# Got None: High School: 0 college: 0
# On address 155 out of 2579
# Got None: High School: 0 college: 0
# On address 156 out of 2579
# Got None: High School: 0 college: 0
# On address 157 out of 2579
# Got None: High School: 0 college: 0
# On address 158 out of 2579
# Got None: High School: 0 college: 0
# On address 159 out of 2579
# Got None: High School: 0 college: 0
# On address 160 out of 2579
# Got None: High School: 0 college: 0
# On address 161 out of 2579
# Got None: High School: 0 college: 0
# On address 162 out of 2579
# Got None: High School: 0 college: 0
# On address 163 out of 2579
# Got None: High School: 0 college: 0
# On address 164 out of 2579
# Got None: High School: 0 college: 0
# On address 165 out of 2579
# Got None: High School: 0 college: 0
# On address 166 out of 2579
# Got None: High School: 0 college: 0
# On address 167 out of 2579
# Got None: High School: 0 college: 0
# On address 168 out of 2579
# Got None: High School: 0 college: 0
# On address 169 out of 2579
# Got None: High School: 0 college: 0
# On address 170 out of 2579
# Got None: High School: 0 college: 0
# On address 171 out of 2579
# Got None: High School: 0 college: 0
# On address 172 out of 2579
# Got None: High School: 0 college: 0
# On address 173 out of 2579
# Got None: High School: 0 college: 0
# On address 174 out of 2579
# Got None: High School: 0 college: 0
# On address 175 out of 2579
# Got None: High School: 0 college: 0
# On address 176 out of 2579
# Got None: High School: 0 college: 0
# On address 177 out of 2579
# Got None: High School: 0 college: 0
# On address 178 out of 2579
# Got None: High School: 0 college: 0
# On address 179 out of 2579
# Got None: High School: 0 college: 0
# On address 180 out of 2579
# Got None: High School: 0 college: 0
# On address 181 out of 2579
# Got None: High School: 0 college: 0
# On address 182 out of 2579
# Got None: High School: 0 college: 0
# On address 183 out of 2579
# Got None: High School: 0 college: 0
# On address 184 out of 2579
# Got None: High School: 0 college: 0
# On address 185 out of 2579
# Got None: High School: 0 college: 0
# On address 186 out of 2579
# Got None: High School: 0 college: 0
# On address 187 out of 2579
# Got None: High School: 0 college: 0
# On address 188 out of 2579
# Got None: High School: 0 college: 0
# On address 189 out of 2579
# Got None: High School: 0 college: 0
# On address 190 out of 2579
# Got None: High School: 0 college: 0
# On address 191 out of 2579
# Got None: High School: 0 college: 0
# On address 192 out of 2579
# Got None: High School: 0 college: 0
# On address 193 out of 2579
# Got None: High School: 0 college: 0
# On address 194 out of 2579
# Got None: High School: 0 college: 0
# On address 195 out of 2579
# Got None: High School: 0 college: 0
# On address 196 out of 2579
# Got None: High School: 0 college: 0
# On address 197 out of 2579
# Got None: High School: 0 college: 0
# On address 198 out of 2579
# Got None: High School: 0 college: 0
# On address 199 out of 2579
# Got None: High School: 0 college: 0
# On address 200 out of 2579
# Got None: High School: 0 college: 0
# On address 201 out of 2579
# Got None: High School: 0 college: 0
# On address 202 out of 2579
# Got None: High School: 0 college: 0
# On address 203 out of 2579
# Got None: High School: 0 college: 0
# On address 204 out of 2579
# Got None: High School: 0 college: 0
# On address 205 out of 2579
# Got None: High School: 0 college: 0
# On address 206 out of 2579
# Got None: High School: 0 college: 0
# On address 207 out of 2579
# Got None: High School: 0 college: 0
# On address 208 out of 2579
# Got None: High School: 0 college: 0
# On address 209 out of 2579
# Got None: High School: 0 college: 0
# On address 210 out of 2579
# Got None: High School: 0 college: 0
# On address 211 out of 2579
# Got None: High School: 0 college: 0
# On address 212 out of 2579
# Got None: High School: 0 college: 0
# On address 213 out of 2579
# Got None: High School: 0 college: 0
# On address 214 out of 2579
# Got None: High School: 0 college: 0
# On address 215 out of 2579
# Got None: High School: 0 college: 0
# On address 216 out of 2579
# Got None: High School: 0 college: 0
# On address 217 out of 2579
# Got None: High School: 0 college: 0
# On address 218 out of 2579
# Got None: High School: 0 college: 0
# On address 219 out of 2579
# Got None: High School: 0 college: 0
# On address 220 out of 2579
# Got None: High School: 0 college: 0
# On address 221 out of 2579
# Got None: High School: 0 college: 0
# On address 222 out of 2579
# Got None: High School: 0 college: 0
# On address 223 out of 2579
# Got None: High School: 0 college: 0
# On address 224 out of 2579
# Got None: High School: 0 college: 0
# On address 225 out of 2579
# Got None: High School: 0 college: 0
# On address 226 out of 2579
# Got None: High School: 0 college: 0
# On address 227 out of 2579
# Got None: High School: 0 college: 0
# On address 228 out of 2579
# Got None: High School: 0 college: 0
# On address 229 out of 2579
# Got None: High School: 0 college: 0
# On address 230 out of 2579
# Got None: High School: 0 college: 0
# On address 231 out of 2579
# Got None: High School: 0 college: 0
# On address 232 out of 2579
# Got None: High School: 0 college: 0
# On address 233 out of 2579
# Got None: High School: 0 college: 0
# On address 234 out of 2579
# Got None: High School: 0 college: 0
# On address 235 out of 2579
# Got None: High School: 0 college: 0
# On address 236 out of 2579
# Got None: High School: 0 college: 0
# On address 237 out of 2579
# Got None: High School: 0 college: 0
# On address 238 out of 2579
# Got None: High School: 0 college: 0
# On address 239 out of 2579
# Got None: High School: 0 college: 0
# On address 240 out of 2579
# Got None: High School: 0 college: 0
# On address 241 out of 2579
# Got None: High School: 0 college: 0
# On address 242 out of 2579
# Got None: High School: 0 college: 0
# On address 243 out of 2579
# Got None: High School: 0 college: 0
# On address 244 out of 2579
# Got None: High School: 0 college: 0
# On address 245 out of 2579
# Got None: High School: 0 college: 0
# On address 246 out of 2579
# Got None: High School: 0 college: 0
# On address 247 out of 2579
# Got None: High School: 0 college: 0
# On address 248 out of 2579
# Got None: High School: 0 college: 0
# On address 249 out of 2579
# Got None: High School: 0 college: 0
# On address 250 out of 2579
# Got None: High School: 0 college: 0
# On address 251 out of 2579
# Got None: High School: 0 college: 0
# On address 252 out of 2579
# Got None: High School: 0 college: 0
# On address 253 out of 2579
# Got None: High School: 0 college: 0
# On address 254 out of 2579
# Got None: High School: 0 college: 0
# On address 255 out of 2579
# Got None: High School: 0 college: 0
# On address 256 out of 2579
# Got None: High School: 0 college: 0
# On address 257 out of 2579
# Got None: High School: 0 college: 0
# On address 258 out of 2579
# Got None: High School: 0 college: 0
# On address 259 out of 2579
# Got None: High School: 0 college: 0
# On address 260 out of 2579
# Got None: High School: 0 college: 0
# On address 261 out of 2579
# Got None: High School: 0 college: 0
# On address 262 out of 2579
# Got None: High School: 0 college: 0
# On address 263 out of 2579
# Got None: High School: 0 college: 0
# On address 264 out of 2579
# Got None: High School: 0 college: 0
# On address 265 out of 2579
# Got None: High School: 0 college: 0
# On address 266 out of 2579
# Got None: High School: 0 college: 0
# On address 267 out of 2579
# Got None: High School: 0 college: 0
# On address 268 out of 2579
# Got None: High School: 0 college: 0
# On address 269 out of 2579
# Got None: High School: 0 college: 0
# On address 270 out of 2579
# Got None: High School: 0 college: 0
# On address 271 out of 2579
# Got None: High School: 0 college: 0
# On address 272 out of 2579
# Got None: High School: 0 college: 0
# On address 273 out of 2579
# Got None: High School: 0 college: 0
# On address 274 out of 2579
# Got None: High School: 0 college: 0
# On address 275 out of 2579
# Got None: High School: 0 college: 0
# On address 276 out of 2579
# Got None: High School: 0 college: 0
# On address 277 out of 2579
# Got None: High School: 0 college: 0
# On address 278 out of 2579
# Got None: High School: 0 college: 0
# On address 279 out of 2579
# Got None: High School: 0 college: 0
# On address 280 out of 2579
# Got None: High School: 0 college: 0
# On address 281 out of 2579
# Got None: High School: 0 college: 0
# On address 282 out of 2579
# Got None: High School: 0 college: 0
# On address 283 out of 2579
# Got None: High School: 0 college: 0
# On address 284 out of 2579
# Got None: High School: 0 college: 0
# On address 285 out of 2579
# Got None: High School: 0 college: 0
# On address 286 out of 2579
# Got None: High School: 0 college: 0
# On address 287 out of 2579
# Got None: High School: 0 college: 0
# On address 288 out of 2579
# Got None: High School: 0 college: 0
# On address 289 out of 2579
# Got None: High School: 0 college: 0
# On address 290 out of 2579
# Got None: High School: 0 college: 0
# On address 291 out of 2579
# Got None: High School: 0 college: 0
# On address 292 out of 2579
# Got None: High School: 0 college: 0
# On address 293 out of 2579
# Got None: High School: 0 college: 0
# On address 294 out of 2579
# Got None: High School: 0 college: 0
# On address 295 out of 2579
# Got None: High School: 0 college: 0
# On address 296 out of 2579
# Got None: High School: 0 college: 0
# On address 297 out of 2579
# Got None: High School: 0 college: 0
# On address 298 out of 2579
# Got None: High School: 0 college: 0
# On address 299 out of 2579
# Got None: High School: 0 college: 0
# On address 300 out of 2579
# Got None: High School: 0 college: 0
# On address 301 out of 2579
# Got None: High School: 0 college: 0
# On address 302 out of 2579
# Got None: High School: 0 college: 0
# On address 303 out of 2579
# Got None: High School: 0 college: 0
# On address 304 out of 2579
# Got None: High School: 0 college: 0
# On address 305 out of 2579
# Got None: High School: 0 college: 0
# On address 306 out of 2579
# Got None: High School: 0 college: 0
# On address 307 out of 2579
# Got None: High School: 0 college: 0
# On address 308 out of 2579
# Got None: High School: 0 college: 0
# On address 309 out of 2579
# Got None: High School: 0 college: 0
# On address 310 out of 2579
# Got None: High School: 0 college: 0
# On address 311 out of 2579
# Got None: High School: 0 college: 0
# On address 312 out of 2579
# Got None: High School: 0 college: 0
# On address 313 out of 2579
# Got None: High School: 0 college: 0
# On address 314 out of 2579
# Got None: High School: 0 college: 0
# On address 315 out of 2579
# Got None: High School: 0 college: 0
# On address 316 out of 2579
# Got None: High School: 0 college: 0
# On address 317 out of 2579
# Got None: High School: 0 college: 0
# On address 318 out of 2579
# Got None: High School: 0 college: 0
# On address 319 out of 2579
# Got None: High School: 0 college: 0
# On address 320 out of 2579
# Got None: High School: 0 college: 0
# On address 321 out of 2579
# Got None: High School: 0 college: 0
# On address 322 out of 2579
# Got None: High School: 0 college: 0
# On address 323 out of 2579
# Got None: High School: 0 college: 0
# On address 324 out of 2579
# Got None: High School: 0 college: 0
# On address 325 out of 2579
# Got None: High School: 0 college: 0
# On address 326 out of 2579
# Got None: High School: 0 college: 0
# On address 327 out of 2579
# Got None: High School: 0 college: 0
# On address 328 out of 2579
# Got None: High School: 0 college: 0
# On address 329 out of 2579
# Got None: High School: 0 college: 0
# On address 330 out of 2579
# Got None: High School: 0 college: 0
# On address 331 out of 2579
# Got None: High School: 0 college: 0
# On address 332 out of 2579
# Got None: High School: 0 college: 0
# On address 333 out of 2579
# Got None: High School: 0 college: 0
# On address 334 out of 2579
# Got None: High School: 0 college: 0
# On address 335 out of 2579
# Got None: High School: 0 college: 0
# On address 336 out of 2579
# Got None: High School: 0 college: 0
# On address 337 out of 2579
# Got None: High School: 0 college: 0
# On address 338 out of 2579
# Got None: High School: 0 college: 0
# On address 339 out of 2579
# Got None: High School: 0 college: 0
# On address 340 out of 2579
# Got None: High School: 0 college: 0
# On address 341 out of 2579
# Got None: High School: 0 college: 0
# On address 342 out of 2579
# Got None: High School: 0 college: 0
# On address 343 out of 2579
# Got None: High School: 0 college: 0
# On address 344 out of 2579
# Got None: High School: 0 college: 0
# On address 345 out of 2579
# Got None: High School: 0 college: 0
# On address 346 out of 2579
# Got None: High School: 0 college: 0
# On address 347 out of 2579
# Got None: High School: 0 college: 0
# On address 348 out of 2579
# Got None: High School: 0 college: 0
# On address 349 out of 2579
# Got None: High School: 0 college: 0
# On address 350 out of 2579
# Got None: High School: 0 college: 0
# On address 351 out of 2579
# Got None: High School: 0 college: 0
# On address 352 out of 2579
# Got None: High School: 0 college: 0
# On address 353 out of 2579
# Got None: High School: 0 college: 0
# On address 354 out of 2579
# Got None: High School: 0 college: 0
# On address 355 out of 2579
# Got None: High School: 0 college: 0
# On address 356 out of 2579
# Got None: High School: 0 college: 0
# On address 357 out of 2579
# Got None: High School: 0 college: 0
# On address 358 out of 2579
# Got None: High School: 0 college: 0
# On address 359 out of 2579
# Got None: High School: 0 college: 0
# On address 360 out of 2579
# Got None: High School: 0 college: 0
# On address 361 out of 2579
# Got None: High School: 0 college: 0
# On address 362 out of 2579
# Got None: High School: 0 college: 0
# On address 363 out of 2579
# Got None: High School: 0 college: 0
# On address 364 out of 2579
# Got None: High School: 0 college: 0
# On address 365 out of 2579
# Got None: High School: 0 college: 0
# On address 366 out of 2579
# Got None: High School: 0 college: 0
# On address 367 out of 2579
# Got None: High School: 0 college: 0
# On address 368 out of 2579
# Got None: High School: 0 college: 0
# On address 369 out of 2579
# Got None: High School: 0 college: 0
# On address 370 out of 2579
# Got None: High School: 0 college: 0
# On address 371 out of 2579
# Got None: High School: 0 college: 0
# On address 372 out of 2579
# Got None: High School: 0 college: 0
# On address 373 out of 2579
# Got None: High School: 0 college: 0
# On address 374 out of 2579
# Got None: High School: 0 college: 0
# On address 375 out of 2579
# Got None: High School: 0 college: 0
# On address 376 out of 2579
# Got None: High School: 0 college: 0
# On address 377 out of 2579
# Got None: High School: 0 college: 0
# On address 378 out of 2579
# Got None: High School: 0 college: 0
# On address 379 out of 2579
# Got None: High School: 0 college: 0
# On address 380 out of 2579
# Got None: High School: 0 college: 0
# On address 381 out of 2579
# Got None: High School: 0 college: 0
# On address 382 out of 2579
# Got None: High School: 0 college: 0
# On address 383 out of 2579
# Got None: High School: 0 college: 0
# On address 384 out of 2579
# Got None: High School: 0 college: 0
# On address 385 out of 2579
# Got None: High School: 0 college: 0
# On address 386 out of 2579
# Got None: High School: 0 college: 0
# On address 387 out of 2579
# Got None: High School: 0 college: 0
# On address 388 out of 2579
# Got None: High School: 0 college: 0
# On address 389 out of 2579
# Got None: High School: 0 college: 0
# On address 390 out of 2579
# Got None: High School: 0 college: 0
# On address 391 out of 2579
# Got None: High School: 0 college: 0
# On address 392 out of 2579
# Got None: High School: 0 college: 0
# On address 393 out of 2579
# Got None: High School: 0 college: 0
# On address 394 out of 2579
# Got None: High School: 0 college: 0
# On address 395 out of 2579
# Got None: High School: 0 college: 0
# On address 396 out of 2579
# Got None: High School: 0 college: 0
# On address 397 out of 2579
# Got None: High School: 0 college: 0
# On address 398 out of 2579
# Got None: High School: 0 college: 0
# On address 399 out of 2579
# Got None: High School: 0 college: 0
# On address 400 out of 2579
# Got None: High School: 0 college: 0
# On address 401 out of 2579
# Got None: High School: 0 college: 0
# On address 402 out of 2579
# Got None: High School: 0 college: 0
# On address 403 out of 2579
# Got None: High School: 0 college: 0
# On address 404 out of 2579
# Got None: High School: 0 college: 0
# On address 405 out of 2579
# Got None: High School: 0 college: 0
# On address 406 out of 2579
# Got None: High School: 0 college: 0
# On address 407 out of 2579
# Got None: High School: 0 college: 0
# On address 408 out of 2579
# Got None: High School: 0 college: 0
# On address 409 out of 2579
# Got None: High School: 0 college: 0
# On address 410 out of 2579
# Got None: High School: 0 college: 0
# On address 411 out of 2579
# Got None: High School: 0 college: 0
# On address 412 out of 2579
# Got None: High School: 0 college: 0
# On address 413 out of 2579
# Got None: High School: 0 college: 0
# On address 414 out of 2579
# Got None: High School: 0 college: 0
# On address 415 out of 2579
# Got None: High School: 0 college: 0
# On address 416 out of 2579
# Got None: High School: 0 college: 0
# On address 417 out of 2579
# Got None: High School: 0 college: 0
# On address 418 out of 2579
# Got None: High School: 0 college: 0
# On address 419 out of 2579
# Got None: High School: 0 college: 0
# On address 420 out of 2579
# Got None: High School: 0 college: 0
# On address 421 out of 2579
# Got None: High School: 0 college: 0
# On address 422 out of 2579
# Got None: High School: 0 college: 0
# On address 423 out of 2579
# Got None: High School: 0 college: 0
# On address 424 out of 2579
# Got None: High School: 0 college: 0
# On address 425 out of 2579
# Got None: High School: 0 college: 0
# On address 426 out of 2579
# Got None: High School: 0 college: 0
# On address 427 out of 2579
# Got None: High School: 0 college: 0
# On address 428 out of 2579
# Got None: High School: 0 college: 0
# On address 429 out of 2579
# Got None: High School: 0 college: 0
# On address 430 out of 2579
# Got None: High School: 0 college: 0
# On address 431 out of 2579
# Got None: High School: 0 college: 0
# On address 432 out of 2579
# Got None: High School: 0 college: 0
# On address 433 out of 2579
# Got None: High School: 0 college: 0
# On address 434 out of 2579
# Got None: High School: 0 college: 0
# On address 435 out of 2579
# Got None: High School: 0 college: 0
# On address 436 out of 2579
# Got None: High School: 0 college: 0
# On address 437 out of 2579
# Got None: High School: 0 college: 0
# On address 438 out of 2579
# Got None: High School: 0 college: 0
# On address 439 out of 2579
# Got None: High School: 0 college: 0
# On address 440 out of 2579
# Got None: High School: 0 college: 0
# On address 441 out of 2579
# Got None: High School: 0 college: 0
# On address 442 out of 2579
# Got None: High School: 0 college: 0
# On address 443 out of 2579
# Got None: High School: 0 college: 0
# On address 444 out of 2579
# Got None: High School: 0 college: 0
# On address 445 out of 2579
# Got None: High School: 0 college: 0
# On address 446 out of 2579
# Got None: High School: 0 college: 0
# On address 447 out of 2579
# Got None: High School: 0 college: 0
# On address 448 out of 2579
# Got None: High School: 0 college: 0
# On address 449 out of 2579
# Got None: High School: 0 college: 0
# On address 450 out of 2579
# Got None: High School: 0 college: 0
# On address 451 out of 2579
# Got None: High School: 0 college: 0
# On address 452 out of 2579
# Got None: High School: 0 college: 0
# On address 453 out of 2579
# Got None: High School: 0 college: 0
# On address 454 out of 2579
# Got None: High School: 0 college: 0
# On address 455 out of 2579
# Got None: High School: 0 college: 0
# On address 456 out of 2579
# Got None: High School: 0 college: 0
# On address 457 out of 2579
# Got None: High School: 0 college: 0
# On address 458 out of 2579
# Got None: High School: 0 college: 0
# On address 459 out of 2579
# Got None: High School: 0 college: 0
# On address 460 out of 2579
# Got None: High School: 0 college: 0
# On address 461 out of 2579
# Got None: High School: 0 college: 0
# On address 462 out of 2579
# Got None: High School: 0 college: 0
# On address 463 out of 2579
# Got None: High School: 0 college: 0
# On address 464 out of 2579
# Got None: High School: 0 college: 0
# On address 465 out of 2579
# Got None: High School: 0 college: 0
# On address 466 out of 2579
# Got None: High School: 0 college: 0
# On address 467 out of 2579
# Got None: High School: 0 college: 0
# On address 468 out of 2579
# Got None: High School: 0 college: 0
# On address 469 out of 2579
# Got None: High School: 0 college: 0
# On address 470 out of 2579
# Got None: High School: 0 college: 0
# On address 471 out of 2579
# Got None: High School: 0 college: 0
# On address 472 out of 2579
# Got None: High School: 0 college: 0
# On address 473 out of 2579
# Got None: High School: 0 college: 0
# On address 474 out of 2579
# Got None: High School: 0 college: 0
# On address 475 out of 2579
# Got None: High School: 0 college: 0
# On address 476 out of 2579
# Got None: High School: 0 college: 0
# On address 477 out of 2579
# Got None: High School: 0 college: 0
# On address 478 out of 2579
# Got None: High School: 0 college: 0
# On address 479 out of 2579
# Got None: High School: 0 college: 0
# On address 480 out of 2579
# Got None: High School: 0 college: 0
# On address 481 out of 2579
# Got None: High School: 0 college: 0
# On address 482 out of 2579
# Got None: High School: 0 college: 0
# On address 483 out of 2579
# Got None: High School: 0 college: 0
# On address 484 out of 2579
# Got None: High School: 0 college: 0
# On address 485 out of 2579
# Got None: High School: 0 college: 0
# On address 486 out of 2579
# Got None: High School: 0 college: 0
# On address 487 out of 2579
# Got None: High School: 0 college: 0
# On address 488 out of 2579
# Got None: High School: 0 college: 0
# On address 489 out of 2579
# Got None: High School: 0 college: 0
# On address 490 out of 2579
# Got None: High School: 0 college: 0
# On address 491 out of 2579
# Got None: High School: 0 college: 0
# On address 492 out of 2579
# Got None: High School: 0 college: 0
# On address 493 out of 2579
# Got None: High School: 0 college: 0
# On address 494 out of 2579
# Got None: High School: 0 college: 0
# On address 495 out of 2579
# Got None: High School: 0 college: 0
# On address 496 out of 2579
# Got None: High School: 0 college: 0
# On address 497 out of 2579
# Got None: High School: 0 college: 0
# On address 498 out of 2579
# Got None: High School: 0 college: 0
# On address 499 out of 2579
# Got None: High School: 0 college: 0
# On address 500 out of 2579
# Got None: High School: 0 college: 0
# On address 501 out of 2579
# Got None: High School: 0 college: 0
# On address 502 out of 2579
# Got None: High School: 0 college: 0
# On address 503 out of 2579
# Got None: High School: 0 college: 0
# On address 504 out of 2579
# Got None: High School: 0 college: 0
# On address 505 out of 2579
# Got None: High School: 0 college: 0
# On address 506 out of 2579
# Got None: High School: 0 college: 0
# On address 507 out of 2579
# Got None: High School: 0 college: 0
# On address 508 out of 2579
# Got None: High School: 0 college: 0
# On address 509 out of 2579
# Got None: High School: 0 college: 0
# On address 510 out of 2579
# Got None: High School: 0 college: 0
# On address 511 out of 2579
# Got None: High School: 0 college: 0
# On address 512 out of 2579
# Got None: High School: 0 college: 0
# On address 513 out of 2579
# Got None: High School: 0 college: 0
# On address 514 out of 2579
# Got None: High School: 0 college: 0
# On address 515 out of 2579
# Got None: High School: 0 college: 0
# On address 516 out of 2579
# Got None: High School: 0 college: 0
# On address 517 out of 2579
# Got None: High School: 0 college: 0
# On address 518 out of 2579
# Got None: High School: 0 college: 0
# On address 519 out of 2579
# Got None: High School: 0 college: 0
# On address 520 out of 2579
# Got None: High School: 0 college: 0
# On address 521 out of 2579
# Got None: High School: 0 college: 0
# On address 522 out of 2579
# Got None: High School: 0 college: 0
# On address 523 out of 2579
# Got None: High School: 0 college: 0
# On address 524 out of 2579
# Got None: High School: 0 college: 0
# On address 525 out of 2579
# Got None: High School: 0 college: 0
# On address 526 out of 2579
# Got None: High School: 0 college: 0
# On address 527 out of 2579
# Got None: High School: 0 college: 0
# On address 528 out of 2579
# Got None: High School: 0 college: 0
# On address 529 out of 2579
# Got None: High School: 0 college: 0
# On address 530 out of 2579
# Got None: High School: 0 college: 0
# On address 531 out of 2579
# Got None: High School: 0 college: 0
# On address 532 out of 2579
# Got None: High School: 0 college: 0
# On address 533 out of 2579
# Got None: High School: 0 college: 0
# On address 534 out of 2579
# Got None: High School: 0 college: 0
# On address 535 out of 2579
# Got None: High School: 0 college: 0
# On address 536 out of 2579
# Got None: High School: 0 college: 0
# On address 537 out of 2579
# Got None: High School: 0 college: 0
# On address 538 out of 2579
# Got None: High School: 0 college: 0
# On address 539 out of 2579
# Got None: High School: 0 college: 0
# On address 540 out of 2579
# Got None: High School: 0 college: 0
# On address 541 out of 2579
# Got None: High School: 0 college: 0
# On address 542 out of 2579
# Got None: High School: 0 college: 0
# On address 543 out of 2579
# Got None: High School: 0 college: 0
# On address 544 out of 2579
# Got None: High School: 0 college: 0
# On address 545 out of 2579
# Got None: High School: 0 college: 0
# On address 546 out of 2579
# Got None: High School: 0 college: 0
# On address 547 out of 2579
# Got None: High School: 0 college: 0
# On address 548 out of 2579
# Got None: High School: 0 college: 0
# On address 549 out of 2579
# Got None: High School: 0 college: 0
# On address 550 out of 2579
# Got None: High School: 0 college: 0
# On address 551 out of 2579
# Got None: High School: 0 college: 0
# On address 552 out of 2579
# Got None: High School: 0 college: 0
# On address 553 out of 2579
# Got None: High School: 0 college: 0
# On address 554 out of 2579
# Got None: High School: 0 college: 0
# On address 555 out of 2579
# Got None: High School: 0 college: 0
# On address 556 out of 2579
# Got None: High School: 0 college: 0
# On address 557 out of 2579
# Got None: High School: 0 college: 0
# On address 558 out of 2579
# Got None: High School: 0 college: 0
# On address 559 out of 2579
# Got None: High School: 0 college: 0
# On address 560 out of 2579
# Got None: High School: 0 college: 0
# On address 561 out of 2579
# Got None: High School: 0 college: 0
# On address 562 out of 2579
# Got None: High School: 0 college: 0
# On address 563 out of 2579
# Got None: High School: 0 college: 0
# On address 564 out of 2579
# Got None: High School: 0 college: 0
# On address 565 out of 2579
# Got None: High School: 0 college: 0
# On address 566 out of 2579
# Got None: High School: 0 college: 0
# On address 567 out of 2579
# Got None: High School: 0 college: 0
# On address 568 out of 2579
# Got None: High School: 0 college: 0
# On address 569 out of 2579
# Got None: High School: 0 college: 0
# On address 570 out of 2579
# Got None: High School: 0 college: 0
# On address 571 out of 2579
# Got None: High School: 0 college: 0
# On address 572 out of 2579
# Got None: High School: 0 college: 0
# On address 573 out of 2579
# Got None: High School: 0 college: 0
# On address 574 out of 2579
# Got None: High School: 0 college: 0
# On address 575 out of 2579
# Got None: High School: 0 college: 0
# On address 576 out of 2579
# Got None: High School: 0 college: 0
# On address 577 out of 2579
# Got None: High School: 0 college: 0
# On address 578 out of 2579
# Got None: High School: 0 college: 0
# On address 579 out of 2579
# Got None: High School: 0 college: 0
# On address 580 out of 2579
# Got None: High School: 0 college: 0
# On address 581 out of 2579
# Got None: High School: 0 college: 0
# On address 582 out of 2579
# Got None: High School: 0 college: 0
# On address 583 out of 2579
# Got None: High School: 0 college: 0
# On address 584 out of 2579
# Got None: High School: 0 college: 0
# On address 585 out of 2579
# Got None: High School: 0 college: 0
# On address 586 out of 2579
# Got None: High School: 0 college: 0
# On address 587 out of 2579
# Got None: High School: 0 college: 0
# On address 588 out of 2579
# Got None: High School: 0 college: 0
# On address 589 out of 2579
# Got None: High School: 0 college: 0
# On address 590 out of 2579
# Got None: High School: 0 college: 0
# On address 591 out of 2579
# Got None: High School: 0 college: 0
# On address 592 out of 2579
# Got None: High School: 0 college: 0
# On address 593 out of 2579
# Got None: High School: 0 college: 0
# On address 594 out of 2579
# Got None: High School: 0 college: 0
# On address 595 out of 2579
# Got None: High School: 0 college: 0
# On address 596 out of 2579
# Got None: High School: 0 college: 0
# On address 597 out of 2579
# Got None: High School: 0 college: 0
# On address 598 out of 2579
# Got None: High School: 0 college: 0
# On address 599 out of 2579
# Got None: High School: 0 college: 0
# On address 600 out of 2579
# Got None: High School: 0 college: 0
# On address 601 out of 2579
# Got None: High School: 0 college: 0
# On address 602 out of 2579
# Got None: High School: 0 college: 0
# On address 603 out of 2579
# Got None: High School: 0 college: 0
# On address 604 out of 2579
# Got None: High School: 0 college: 0
# On address 605 out of 2579
# Got None: High School: 0 college: 0
# On address 606 out of 2579
# Got None: High School: 0 college: 0
# On address 607 out of 2579
# Got None: High School: 0 college: 0
# On address 608 out of 2579
# Got None: High School: 0 college: 0
# On address 609 out of 2579
# Got None: High School: 0 college: 0
# On address 610 out of 2579
# Got None: High School: 0 college: 0
# On address 611 out of 2579
# Got None: High School: 0 college: 0
# On address 612 out of 2579
# Got None: High School: 0 college: 0
# On address 613 out of 2579
# Got None: High School: 0 college: 0
# On address 614 out of 2579
# Got None: High School: 0 college: 0
# On address 615 out of 2579
# Got None: High School: 0 college: 0
# On address 616 out of 2579
# Got None: High School: 0 college: 0
# On address 617 out of 2579
# Got None: High School: 0 college: 0
# On address 618 out of 2579
# Got None: High School: 0 college: 0
# On address 619 out of 2579
# Got None: High School: 0 college: 0
# On address 620 out of 2579
# Got None: High School: 0 college: 0
# On address 621 out of 2579
# Got None: High School: 0 college: 0
# On address 622 out of 2579
# Got None: High School: 0 college: 0
# On address 623 out of 2579
# Got None: High School: 0 college: 0
# On address 624 out of 2579
# Got None: High School: 0 college: 0
# On address 625 out of 2579
# Got None: High School: 0 college: 0
# On address 626 out of 2579
# Got None: High School: 0 college: 0
# On address 627 out of 2579
# Got None: High School: 0 college: 0
# On address 628 out of 2579
# Got None: High School: 0 college: 0
# On address 629 out of 2579
# Got None: High School: 0 college: 0
# On address 630 out of 2579
# Got None: High School: 0 college: 0
# On address 631 out of 2579
# Got None: High School: 0 college: 0
# On address 632 out of 2579
# Got None: High School: 0 college: 0
# On address 633 out of 2579
# Got None: High School: 0 college: 0
# On address 634 out of 2579
# Got None: High School: 0 college: 0
# On address 635 out of 2579
# Got None: High School: 0 college: 0
# On address 636 out of 2579
# Got None: High School: 0 college: 0
# On address 637 out of 2579
# Got None: High School: 0 college: 0
# On address 638 out of 2579
# Got None: High School: 0 college: 0
# On address 639 out of 2579
# Got None: High School: 0 college: 0
# On address 640 out of 2579
# Got None: High School: 0 college: 0
# On address 641 out of 2579
# Got None: High School: 0 college: 0
# On address 642 out of 2579
# Got None: High School: 0 college: 0
# On address 643 out of 2579
# Got None: High School: 0 college: 0
# On address 644 out of 2579
# Got None: High School: 0 college: 0
# On address 645 out of 2579
# Got None: High School: 0 college: 0
# On address 646 out of 2579
# Got None: High School: 0 college: 0
# On address 647 out of 2579
# Got None: High School: 0 college: 0
# On address 648 out of 2579
# Got None: High School: 0 college: 0
# On address 649 out of 2579
# Got None: High School: 0 college: 0
# On address 650 out of 2579
# Got None: High School: 0 college: 0
# On address 651 out of 2579
# Got None: High School: 0 college: 0
# On address 652 out of 2579
# Got None: High School: 0 college: 0
# On address 653 out of 2579
# Got None: High School: 0 college: 0
# On address 654 out of 2579
# Got None: High School: 0 college: 0
# On address 655 out of 2579
# Got None: High School: 0 college: 0
# On address 656 out of 2579
# Got None: High School: 0 college: 0
# On address 657 out of 2579
# Got None: High School: 0 college: 0
# On address 658 out of 2579
# Got None: High School: 0 college: 0
# On address 659 out of 2579
# Got None: High School: 0 college: 0
# On address 660 out of 2579
# Got None: High School: 0 college: 0
# On address 661 out of 2579
# Got None: High School: 0 college: 0
# On address 662 out of 2579
# Got None: High School: 0 college: 0
# On address 663 out of 2579
# Got None: High School: 0 college: 0
# On address 664 out of 2579
# Got None: High School: 0 college: 0
# On address 665 out of 2579
# Got None: High School: 0 college: 0
# On address 666 out of 2579
# Got None: High School: 0 college: 0
# On address 667 out of 2579
# Got None: High School: 0 college: 0
# On address 668 out of 2579
# Got None: High School: 0 college: 0
# On address 669 out of 2579
# Got None: High School: 0 college: 0
# On address 670 out of 2579
# Got None: High School: 0 college: 0
# On address 671 out of 2579
# Got None: High School: 0 college: 0
# On address 672 out of 2579
# Got None: High School: 0 college: 0
# On address 673 out of 2579
# Got None: High School: 0 college: 0
# On address 674 out of 2579
# Got None: High School: 0 college: 0
# On address 675 out of 2579
# Got None: High School: 0 college: 0
# On address 676 out of 2579
# Got None: High School: 0 college: 0
# On address 677 out of 2579
# Got None: High School: 0 college: 0
# On address 678 out of 2579
# Got None: High School: 0 college: 0
# On address 679 out of 2579
# Got None: High School: 0 college: 0
# On address 680 out of 2579
# Got None: High School: 0 college: 0
# On address 681 out of 2579
# Got None: High School: 0 college: 0
# On address 682 out of 2579
# Got None: High School: 0 college: 0
# On address 683 out of 2579
# Got None: High School: 0 college: 0
# On address 684 out of 2579
# Got None: High School: 0 college: 0
# On address 685 out of 2579
# Got None: High School: 0 college: 0
# On address 686 out of 2579
# Got None: High School: 0 college: 0
# On address 687 out of 2579
# Got None: High School: 0 college: 0
# On address 688 out of 2579
# Got None: High School: 0 college: 0
# On address 689 out of 2579
# Got None: High School: 0 college: 0
# On address 690 out of 2579
# Got None: High School: 0 college: 0
# On address 691 out of 2579
# Got None: High School: 0 college: 0
# On address 692 out of 2579
# Got None: High School: 0 college: 0
# On address 693 out of 2579
# Got None: High School: 0 college: 0
# On address 694 out of 2579
# Got None: High School: 0 college: 0
# On address 695 out of 2579
# Got None: High School: 0 college: 0
# On address 696 out of 2579
# Got None: High School: 0 college: 0
# On address 697 out of 2579
# Got None: High School: 0 college: 0
# On address 698 out of 2579
# Got None: High School: 0 college: 0
# On address 699 out of 2579
# Got None: High School: 0 college: 0
# On address 700 out of 2579
# Got None: High School: 0 college: 0
# On address 701 out of 2579
# Got None: High School: 0 college: 0
# On address 702 out of 2579
# Got None: High School: 0 college: 0
# On address 703 out of 2579
# Got None: High School: 0 college: 0
# On address 704 out of 2579
# Got None: High School: 0 college: 0
# On address 705 out of 2579
# Got None: High School: 0 college: 0
# On address 706 out of 2579
# Got None: High School: 0 college: 0
# On address 707 out of 2579
# Got None: High School: 0 college: 0
# On address 708 out of 2579
# Got None: High School: 0 college: 0
# On address 709 out of 2579
# Got None: High School: 0 college: 0
# On address 710 out of 2579
# Got None: High School: 0 college: 0
# On address 711 out of 2579
# Got None: High School: 0 college: 0
# On address 712 out of 2579
# Got None: High School: 0 college: 0
# On address 713 out of 2579
# Got None: High School: 0 college: 0
# On address 714 out of 2579
# Got None: High School: 0 college: 0
# On address 715 out of 2579
# Got None: High School: 0 college: 0
# On address 716 out of 2579
# Got None: High School: 0 college: 0
# On address 717 out of 2579
# Got None: High School: 0 college: 0
# On address 718 out of 2579
# Got None: High School: 0 college: 0
# On address 719 out of 2579
# Got None: High School: 0 college: 0
# On address 720 out of 2579
# Got None: High School: 0 college: 0
# On address 721 out of 2579
# Got None: High School: 0 college: 0
# On address 722 out of 2579
# Got None: High School: 0 college: 0
# On address 723 out of 2579
# Got None: High School: 0 college: 0
# On address 724 out of 2579
# Got None: High School: 0 college: 0
# On address 725 out of 2579
# Got None: High School: 0 college: 0
# On address 726 out of 2579
# Got None: High School: 0 college: 0
# On address 727 out of 2579
# Got None: High School: 0 college: 0
# On address 728 out of 2579
# Got None: High School: 0 college: 0
# On address 729 out of 2579
# Got None: High School: 0 college: 0
# On address 730 out of 2579
# Got None: High School: 0 college: 0
# On address 731 out of 2579
# Got None: High School: 0 college: 0
# On address 732 out of 2579
# Got None: High School: 0 college: 0
# On address 733 out of 2579
# Got None: High School: 0 college: 0
# On address 734 out of 2579
# Got None: High School: 0 college: 0
# On address 735 out of 2579
# Got None: High School: 0 college: 0
# On address 736 out of 2579
# Got None: High School: 0 college: 0
# On address 737 out of 2579
# Got None: High School: 0 college: 0
# On address 738 out of 2579
# Got None: High School: 0 college: 0
# On address 739 out of 2579
# Got None: High School: 0 college: 0
# On address 740 out of 2579
# Got None: High School: 0 college: 0
# On address 741 out of 2579
# Got None: High School: 0 college: 0
# On address 742 out of 2579
# Got None: High School: 0 college: 0
# On address 743 out of 2579
# Got None: High School: 0 college: 0
# On address 744 out of 2579
# Got None: High School: 0 college: 0
# On address 745 out of 2579
# Got None: High School: 0 college: 0
# On address 746 out of 2579
# Got None: High School: 0 college: 0
# On address 747 out of 2579
# Got None: High School: 0 college: 0
# On address 748 out of 2579
# Got None: High School: 0 college: 0
# On address 749 out of 2579
# Got None: High School: 0 college: 0
# On address 750 out of 2579
# Got None: High School: 0 college: 0
# On address 751 out of 2579
# Got None: High School: 0 college: 0
# On address 752 out of 2579
# Got None: High School: 0 college: 0
# On address 753 out of 2579
# Got None: High School: 0 college: 0
# On address 754 out of 2579
# Got None: High School: 0 college: 0
# On address 755 out of 2579
# Got None: High School: 0 college: 0
# On address 756 out of 2579
# Got None: High School: 0 college: 0
# On address 757 out of 2579
# Got None: High School: 0 college: 0
# On address 758 out of 2579
# Got None: High School: 0 college: 0
# On address 759 out of 2579
# Got None: High School: 0 college: 0
# On address 760 out of 2579
# Got None: High School: 0 college: 0
# On address 761 out of 2579
# Got None: High School: 0 college: 0
# On address 762 out of 2579
# Got None: High School: 0 college: 0
# On address 763 out of 2579
# Got None: High School: 0 college: 0
# On address 764 out of 2579
# ...
# On address 1869 out of 2579
# Got None: High School: 0 college: 0
# On address 1870 out of 2579
# Got None: High School: 0 college: 0
# On address 1871 out of 2579
# Got None: High School: 0 college: 0
# On address 1872 out of 2579
# Got None: High School: 0 college: 0
# On address 1873 out of 2579
# Got None: High School: 0 college: 0
# On address 1874 out of 2579
# Got None: High School: 0 college: 0
# On address 1875 out of 2579
# Got None: High School: 0 college: 0
# On address 1876 out of 2579
# Got None: High School: 0 college: 0
# On address 1877 out of 2579
# Got None: High School: 0 college: 0
# On address 1878 out of 2579
# Got None: High School: 0 college: 0
# On address 1879 out of 2579
# Got None: High School: 0 college: 0
# On address 1880 out of 2579
# Got None: High School: 0 college: 0
# On address 1881 out of 2579
# Got None: High School: 0 college: 0
# On address 1882 out of 2579
# Got None: High School: 0 college: 0
# On address 1883 out of 2579
# Got None: High School: 0 college: 0
# On address 1884 out of 2579
# Got None: High School: 0 college: 0
# On address 1885 out of 2579
# Got None: High School: 0 college: 0
# On address 1886 out of 2579
# Got None: High School: 0 college: 0
# On address 1887 out of 2579
# Got None: High School: 0 college: 0
# On address 1888 out of 2579
# Got None: High School: 0 college: 0
# On address 1889 out of 2579
# Got None: High School: 0 college: 0
# On address 1890 out of 2579
# Got None: High School: 0 college: 0
# On address 1891 out of 2579
# Got None: High School: 0 college: 0
# On address 1892 out of 2579
# Got None: High School: 0 college: 0
# On address 1893 out of 2579
# Got None: High School: 0 college: 0
# On address 1894 out of 2579
# Got None: High School: 0 college: 0
# On address 1895 out of 2579
# Got None: High School: 0 college: 0
# On address 1896 out of 2579
# Got None: High School: 0 college: 0
# On address 1897 out of 2579
# Got None: High School: 0 college: 0
# On address 1898 out of 2579
# Got None: High School: 0 college: 0
# On address 1899 out of 2579
# Got None: High School: 0 college: 0
# On address 1900 out of 2579
# Got None: High School: 0 college: 0
# On address 1901 out of 2579
# Got None: High School: 0 college: 0
# On address 1902 out of 2579
# Got None: High School: 0 college: 0
# On address 1903 out of 2579
# Got None: High School: 0 college: 0
# On address 1904 out of 2579
# Got None: High School: 0 college: 0
# On address 1905 out of 2579
# Got None: High School: 0 college: 0
# On address 1906 out of 2579
# Got None: High School: 0 college: 0
# On address 1907 out of 2579
# Got None: High School: 0 college: 0
# On address 1908 out of 2579
# Got None: High School: 0 college: 0
# On address 1909 out of 2579
# Got None: High School: 0 college: 0
# On address 1910 out of 2579
# Got None: High School: 0 college: 0
# On address 1911 out of 2579
# Got None: High School: 0 college: 0
# On address 1912 out of 2579
# Got None: High School: 0 college: 0
# On address 1913 out of 2579
# Got None: High School: 0 college: 0
# On address 1914 out of 2579
# Got None: High School: 0 college: 0
# On address 1915 out of 2579
# Got None: High School: 0 college: 0
# On address 1916 out of 2579
# Got None: High School: 0 college: 0
# On address 1917 out of 2579
# Got None: High School: 0 college: 0
# On address 1918 out of 2579
# Got None: High School: 0 college: 0
# On address 1919 out of 2579
# Got None: High School: 0 college: 0
# On address 1920 out of 2579
# Got None: High School: 0 college: 0
# On address 1921 out of 2579
# Got None: High School: 0 college: 0
# On address 1922 out of 2579
# Got None: High School: 0 college: 0
# On address 1923 out of 2579
# Got None: High School: 0 college: 0
# On address 1924 out of 2579
# Got None: High School: 0 college: 0
# On address 1925 out of 2579
# Got None: High School: 0 college: 0
# On address 1926 out of 2579
# Got None: High School: 0 college: 0
# On address 1927 out of 2579
# Got None: High School: 0 college: 0
# On address 1928 out of 2579
# Got None: High School: 0 college: 0
# On address 1929 out of 2579
# Got None: High School: 0 college: 0
# On address 1930 out of 2579
# Got None: High School: 0 college: 0
# On address 1931 out of 2579
# Got None: High School: 0 college: 0
# On address 1932 out of 2579
# Got None: High School: 0 college: 0
# On address 1933 out of 2579
# Got None: High School: 0 college: 0
# On address 1934 out of 2579
# Got None: High School: 0 college: 0
# On address 1935 out of 2579
# Got None: High School: 0 college: 0
# On address 1936 out of 2579
# Got None: High School: 0 college: 0
# On address 1937 out of 2579
# Got None: High School: 0 college: 0
# On address 1938 out of 2579
# Got None: High School: 0 college: 0
# On address 1939 out of 2579
# Got None: High School: 0 college: 0
# On address 1940 out of 2579
# Got None: High School: 0 college: 0
# On address 1941 out of 2579
# Got None: High School: 0 college: 0
# On address 1942 out of 2579
# Got None: High School: 0 college: 0
# On address 1943 out of 2579
# Got None: High School: 0 college: 0
# On address 1944 out of 2579
# Got None: High School: 0 college: 0
# On address 1945 out of 2579
# Got None: High School: 0 college: 0
# On address 1946 out of 2579
# Got None: High School: 0 college: 0
# On address 1947 out of 2579
# Got None: High School: 0 college: 0
# On address 1948 out of 2579
# Got None: High School: 0 college: 0
# On address 1949 out of 2579
# Got None: High School: 0 college: 0
# On address 1950 out of 2579
# Got None: High School: 0 college: 0
# On address 1951 out of 2579
# Got None: High School: 0 college: 0
# On address 1952 out of 2579
# Got None: High School: 0 college: 0
# On address 1953 out of 2579
# Got None: High School: 0 college: 0
# On address 1954 out of 2579
# Got None: High School: 0 college: 0
# On address 1955 out of 2579
# Got None: High School: 0 college: 0
# On address 1956 out of 2579
# Got None: High School: 0 college: 0
# On address 1957 out of 2579
# Got None: High School: 0 college: 0
# On address 1958 out of 2579
# Got None: High School: 0 college: 0
# On address 1959 out of 2579
# Got None: High School: 0 college: 0
# On address 1960 out of 2579
# Got None: High School: 0 college: 0
# On address 1961 out of 2579
# Got None: High School: 0 college: 0
# On address 1962 out of 2579
# Got None: High School: 0 college: 0
# On address 1963 out of 2579
# Got None: High School: 0 college: 0
# On address 1964 out of 2579
# Got None: High School: 0 college: 0
# On address 1965 out of 2579
# Got None: High School: 0 college: 0
# On address 1966 out of 2579
# Got None: High School: 0 college: 0
# On address 1967 out of 2579
# Got None: High School: 0 college: 0
# On address 1968 out of 2579
# Got None: High School: 0 college: 0
# On address 1969 out of 2579
# Got None: High School: 0 college: 0
# On address 1970 out of 2579
# Got None: High School: 0 college: 0
# On address 1971 out of 2579
# Got None: High School: 0 college: 0
# On address 1972 out of 2579
# Got None: High School: 0 college: 0
# On address 1973 out of 2579
# Got None: High School: 0 college: 0
# On address 1974 out of 2579
# Got None: High School: 0 college: 0
# On address 1975 out of 2579
# Got None: High School: 0 college: 0
# On address 1976 out of 2579
# Got None: High School: 0 college: 0
# On address 1977 out of 2579
# Got None: High School: 0 college: 0
# On address 1978 out of 2579
# Got None: High School: 0 college: 0
# On address 1979 out of 2579
# Got None: High School: 0 college: 0
# On address 1980 out of 2579
# Got None: High School: 0 college: 0
# On address 1981 out of 2579
# Got None: High School: 0 college: 0
# On address 1982 out of 2579
# Got None: High School: 0 college: 0
# On address 1983 out of 2579
# Got None: High School: 0 college: 0
# On address 1984 out of 2579
# Got None: High School: 0 college: 0
# On address 1985 out of 2579
# Got None: High School: 0 college: 0
# On address 1986 out of 2579
# Got None: High School: 0 college: 0
# On address 1987 out of 2579
# Got None: High School: 0 college: 0
# On address 1988 out of 2579
# Got None: High School: 0 college: 0
# On address 1989 out of 2579
# Got None: High School: 0 college: 0
# On address 1990 out of 2579
# Got None: High School: 0 college: 0
# On address 1991 out of 2579
# Got None: High School: 0 college: 0
# On address 1992 out of 2579
# Got None: High School: 0 college: 0
# On address 1993 out of 2579
# Got None: High School: 0 college: 0
# On address 1994 out of 2579
# Got None: High School: 0 college: 0
# On address 1995 out of 2579
# Got None: High School: 0 college: 0
# On address 1996 out of 2579
# Got None: High School: 0 college: 0
# On address 1997 out of 2579
# Got None: High School: 0 college: 0
# On address 1998 out of 2579
# Got None: High School: 0 college: 0
# On address 1999 out of 2579
# Got None: High School: 0 college: 0
# On address 2000 out of 2579
# Got None: High School: 0 college: 0
# On address 2001 out of 2579
# Got None: High School: 0 college: 0
# On address 2002 out of 2579
# Got None: High School: 0 college: 0
# On address 2003 out of 2579
# Got None: High School: 0 college: 0
# On address 2004 out of 2579
# Got None: High School: 0 college: 0
# On address 2005 out of 2579
# Got None: High School: 0 college: 0
# On address 2006 out of 2579
# Got None: High School: 0 college: 0
# On address 2007 out of 2579
# Got None: High School: 0 college: 0
# On address 2008 out of 2579
# Got None: High School: 0 college: 0
# On address 2009 out of 2579
# Got None: High School: 0 college: 0
# On address 2010 out of 2579
# Got None: High School: 0 college: 0
# On address 2011 out of 2579
# Got None: High School: 0 college: 0
# On address 2012 out of 2579
# Got None: High School: 0 college: 0
# On address 2013 out of 2579
# Got None: High School: 0 college: 0
# On address 2014 out of 2579
# Got None: High School: 0 college: 0
# On address 2015 out of 2579
# Got None: High School: 0 college: 0
# On address 2016 out of 2579
# Got None: High School: 0 college: 0
# On address 2017 out of 2579
# Got None: High School: 0 college: 0
# On address 2018 out of 2579
# Got None: High School: 0 college: 0
# On address 2019 out of 2579
# Got None: High School: 0 college: 0
# On address 2020 out of 2579
# Got None: High School: 0 college: 0
# On address 2021 out of 2579
# Got None: High School: 0 college: 0
# On address 2022 out of 2579
# Got None: High School: 0 college: 0
# On address 2023 out of 2579
# Got None: High School: 0 college: 0
# On address 2024 out of 2579
# Got None: High School: 0 college: 0
# On address 2025 out of 2579
# Got None: High School: 0 college: 0
# On address 2026 out of 2579
# Got None: High School: 0 college: 0
# On address 2027 out of 2579
# Got None: High School: 0 college: 0
# On address 2028 out of 2579
# Got None: High School: 0 college: 0
# On address 2029 out of 2579
# Got None: High School: 0 college: 0
# On address 2030 out of 2579
# Got None: High School: 0 college: 0
# On address 2031 out of 2579
# Got None: High School: 0 college: 0
# On address 2032 out of 2579
# Got None: High School: 0 college: 0
# On address 2033 out of 2579
# Got None: High School: 0 college: 0
# On address 2034 out of 2579
# Got None: High School: 0 college: 0
# On address 2035 out of 2579
# Got None: High School: 0 college: 0
# On address 2036 out of 2579
# Got None: High School: 0 college: 0
# On address 2037 out of 2579
# Got None: High School: 0 college: 0
# On address 2038 out of 2579
# Got None: High School: 0 college: 0
# On address 2039 out of 2579
# Got None: High School: 0 college: 0
# On address 2040 out of 2579
# Got None: High School: 0 college: 0
# On address 2041 out of 2579
# Got None: High School: 0 college: 0
# On address 2042 out of 2579
# Got None: High School: 0 college: 0
# On address 2043 out of 2579
# Got None: High School: 0 college: 0
# On address 2044 out of 2579
# Got None: High School: 0 college: 0
# On address 2045 out of 2579
# Got None: High School: 0 college: 0
# On address 2046 out of 2579
# Got None: High School: 0 college: 0
# On address 2047 out of 2579
# Got None: High School: 0 college: 0
# On address 2048 out of 2579
# Got None: High School: 0 college: 0
# On address 2049 out of 2579
# Got None: High School: 0 college: 0
# On address 2050 out of 2579
# Got None: High School: 0 college: 0
# On address 2051 out of 2579
# Got None: High School: 0 college: 0
# On address 2052 out of 2579
# Got None: High School: 0 college: 0
# On address 2053 out of 2579
# Got None: High School: 0 college: 0
# On address 2054 out of 2579
# Got None: High School: 0 college: 0
# On address 2055 out of 2579
# Got None: High School: 0 college: 0
# On address 2056 out of 2579
# Got None: High School: 0 college: 0
# On address 2057 out of 2579
# Got None: High School: 0 college: 0
# On address 2058 out of 2579
# Got None: High School: 0 college: 0
# On address 2059 out of 2579
# Got None: High School: 0 college: 0
# On address 2060 out of 2579
# Got None: High School: 0 college: 0
# On address 2061 out of 2579
# Got None: High School: 0 college: 0
# On address 2062 out of 2579
# Got None: High School: 0 college: 0
# On address 2063 out of 2579
# Got None: High School: 0 college: 0
# On address 2064 out of 2579
# Got None: High School: 0 college: 0
# On address 2065 out of 2579
# Got None: High School: 0 college: 0
# On address 2066 out of 2579
# Got None: High School: 0 college: 0
# On address 2067 out of 2579
# Got None: High School: 0 college: 0
# On address 2068 out of 2579
# Got None: High School: 0 college: 0
# On address 2069 out of 2579
# Got None: High School: 0 college: 0
# On address 2070 out of 2579
# Got None: High School: 0 college: 0
# On address 2071 out of 2579
# Got None: High School: 0 college: 0
# On address 2072 out of 2579
# Got None: High School: 0 college: 0
# On address 2073 out of 2579
# Got None: High School: 0 college: 0
# On address 2074 out of 2579
# Got None: High School: 0 college: 0
# On address 2075 out of 2579
# Got None: High School: 0 college: 0
# On address 2076 out of 2579
# Got None: High School: 0 college: 0
# On address 2077 out of 2579
# Got None: High School: 0 college: 0
# On address 2078 out of 2579
# Got None: High School: 0 college: 0
# On address 2079 out of 2579
# Got None: High School: 0 college: 0
# On address 2080 out of 2579
# Got None: High School: 0 college: 0
# On address 2081 out of 2579
# Got None: High School: 0 college: 0
# On address 2082 out of 2579
# Got None: High School: 0 college: 0
# On address 2083 out of 2579
# Got None: High School: 0 college: 0
# On address 2084 out of 2579
# Got None: High School: 0 college: 0
# On address 2085 out of 2579
# Got None: High School: 0 college: 0
# On address 2086 out of 2579
# Got None: High School: 0 college: 0
# On address 2087 out of 2579
# Got None: High School: 0 college: 0
# On address 2088 out of 2579
# Got None: High School: 0 college: 0
# On address 2089 out of 2579
# Got None: High School: 0 college: 0
# On address 2090 out of 2579
# Got None: High School: 0 college: 0
# On address 2091 out of 2579
# Got None: High School: 0 college: 0
# On address 2092 out of 2579
# Got None: High School: 0 college: 0
# On address 2093 out of 2579
# Got None: High School: 0 college: 0
# On address 2094 out of 2579
# Got None: High School: 0 college: 0
# On address 2095 out of 2579
# Got None: High School: 0 college: 0
# On address 2096 out of 2579
# Got None: High School: 0 college: 0
# On address 2097 out of 2579
# Got None: High School: 0 college: 0
# On address 2098 out of 2579
# Got None: High School: 0 college: 0
# On address 2099 out of 2579
# Got None: High School: 0 college: 0
# On address 2100 out of 2579
# Got None: High School: 0 college: 0
# On address 2101 out of 2579
# Got None: High School: 0 college: 0
# On address 2102 out of 2579
# Got None: High School: 0 college: 0
# On address 2103 out of 2579
# Got None: High School: 0 college: 0
# On address 2104 out of 2579
# Got None: High School: 0 college: 0
# On address 2105 out of 2579
# Got None: High School: 0 college: 0
# On address 2106 out of 2579
# Got None: High School: 0 college: 0
# On address 2107 out of 2579
# Got None: High School: 0 college: 0
# On address 2108 out of 2579
# Got None: High School: 0 college: 0
# On address 2109 out of 2579
# Got None: High School: 0 college: 0
# On address 2110 out of 2579
# Got None: High School: 0 college: 0
# On address 2111 out of 2579
# Got None: High School: 0 college: 0
# On address 2112 out of 2579
# Got None: High School: 0 college: 0
# On address 2113 out of 2579
# Got None: High School: 0 college: 0
# On address 2114 out of 2579
# Got None: High School: 0 college: 0
# On address 2115 out of 2579
# Got None: High School: 0 college: 0
# On address 2116 out of 2579
# Got None: High School: 0 college: 0
# On address 2117 out of 2579
# Got None: High School: 0 college: 0
# On address 2118 out of 2579
# Got None: High School: 0 college: 0

# %%
clean_df.shape
# Out:
# (2531, 81)

# %%
#looking at zoning - Will only keep residential
clean_df.MSZoning.value_counts()
# Out:
# RL         2008
# RM          418
# FV          113
# RH           21
# C (all)      17
# I (all)       2
# A (agr)       1
# Name: MSZoning, dtype: int64

# %%
#drop non residential properties 
clean_df = clean_df[clean_df.MSZoning != 'C (all)']
clean_df = clean_df[clean_df.MSZoning != 'I (all)']
clean_df = clean_df[clean_df.MSZoning != 'A (agr)']

# %%
#check 
clean_df.MSZoning.value_counts()
# Out:
# RL    2008
# RM     418
# FV     113
# RH      21
# Name: MSZoning, dtype: int64

# %%
# check to see what it looks like after dropping CIA 
clean_df['Functional'].value_counts()

# %%
#removing outliers from GrLivArea & LotArea & TotalBsmtSF
clean_df = clean_df.loc[(clean_df['GrLivArea']<4000) & (clean_df['LotArea']<100000)\
                        & (clean_df['TotalBsmtSF']<3000),:]

# %% [markdown]
# #### Getting Curb Appeal Column

# %%
clean_df['MasVnrArea'].replace(to_replace=0, value=np.nan, inplace=True)
clean_df['MasVnrArea_bin'] = pd.qcut(clean_df['MasVnrArea'], q=5)
clean_df['MasVnrArea_vals'] = pd.cut(x=clean_df['MasVnrArea'],\
                                 bins=[0.999, 104.0, 169.4, 242.0, 363.6,\
                                       1600], labels=[1,2,3,4,5])

clean_df['LotFrontage'].replace(to_replace=0, value=np.nan, inplace=True)
clean_df['LotFrontage_bin'] = pd.qcut(clean_df['LotFrontage'], q=5)
clean_df['LotFrontage_vals'] = pd.cut(x=clean_df['LotFrontage'],\
                                 bins=[20.999, 52.0, 62.0, 72.0, 82.0,\
                                       313.0], labels=[1,2,3,4,5])

clean_df = clean_df.replace(np.nan, 0)

clean_df = clean_df.replace({"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})

clean_df['Street'] = clean_df['Street'].replace({"Grvl":2, "Pave":4})

clean_df['LotShape'] = clean_df['LotShape'].replace({"Reg":1.5, "IR1":3, "IR3":3, "IR2":4.5})

clean_df['LandContour'] = clean_df['LandContour'].replace({"Bnk":1.25, "Lvl":2.5, "Low":3.75, "HLS":5})

clean_df['LotConfig'] = clean_df['LotConfig'].replace({"FR2":1, "Inside":2, "Corner":3, "FR3":4, "CulDSac":5})

clean_df['LandSlope'] = clean_df['LandSlope'].replace({"Gtl":1.5, "Mod":3, "Sev":5})

clean_df['RoofStyle'] = clean_df['RoofStyle'].replace({"Gambrel":1, "Gable":2, "Mansard":3, "Flat":4,"Hip":5, "Shed":5})

clean_df['RoofMatl'] = clean_df['RoofMatl'].replace({"Roll":1, "CompShg":2, "Metal":2, "Tar&Grv":2.5,\
  "WdShake":3, "Membran":4, "WdShngl":5})

clean_df['Exterior1st'] = clean_df['Exterior1st'].replace({"AsphShn":1, "CBlock":1, "AsbShng":2, "Wd Sdng":2.5,\
  "WdShing":2.5, "Stucco":2.5, "MetalSd":3, "BrkComm":3, "HdBoard":3.5,\
  "Plywood":4, "BrkFace":4, "CemntBd":4.5, "VinylSd":4.5, "PreCast":5,\
  "ImStucc":5})

# %%
clean_df['curb_appeal']= (clean_df['MasVnrArea_vals'] + clean_df['LotFrontage_vals']\
+ clean_df['Street'] + clean_df['LotShape'] + clean_df['LandContour'] + clean_df['LotConfig']\
+ clean_df['LandSlope'] + clean_df['RoofStyle'] + clean_df['RoofMatl'] + clean_df['Exterior1st']\
+ clean_df['ExterQual'] + clean_df['ExterCond'])/12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8a48724d27bf> in <module>
#       2 + clean_df['Street'] + clean_df['LotShape'] + clean_df['LandContour'] + clean_df['LotConfig']\
#       3 + clean_df['LandSlope'] + clean_df['RoofStyle'] + clean_df['RoofMatl'] + clean_df['Exterior1st']\
# ----> 4 + clean_df['ExterQual'] + clean_df['ExterCond'])/12
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#     498         lvalues = extract_array(left, extract_numpy=True)
#     499         rvalues = extract_array(right, extract_numpy=True)
# --> 500         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     501
#     502         return _construct_result(left, result, index=left.index, name=res_name)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op, str_rep)
#     191         #  by dispatch_to_extension_op.
#     192         # Timedelta is included because numexpr will fail on it, see GH#31457
# --> 193         res_values = dispatch_to_extension_op(op, lvalues, rvalues)
#     194
#     195     else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/dispatch.py in dispatch_to_extension_op(op, left, right)
#     123     # The op calls will raise TypeError if the op is not defined
#     124     # on the ExtensionArray
# --> 125     res_values = op(left, right)
#     126     return res_values
#
# TypeError: unsupported operand type(s) for +: 'Categorical' and 'Categorical'

# %%
#clean_df['MSZoning'] == "FV", "RH", "RL", "RP", "RM"

# %% [markdown]
# # Keeping columns

# %%
# 0 'SalePriceLog' ADDing New Column 
clean_df['SalePriceLog'] = np.log10(clean_df['SalePrice'])
clean_df['SalePriceLog'] = clean_df['SalePriceLog'].astype(np.int64)

# %%
# 5 Curb Appeal

# %%
# 6 utilities
clean_df.Utilities = clean_df.Utilities.replace({'AllPub':1,'NoSewr':0})

# %%
# 7 Neighborhood - replace with real estate neighborhood
clean_df.Neighborhood_y = clean_df.Neighborhood_y.replace({'MeadowV':1,"Br'Dale":2, 'IDOT&RR':3, 'BrkSide':4, 'OldTown':5, 'Edwards':6, 'S&W ISU':7, 'Sawyer':8, 'NoPkVil':9,\
                           'N Ames':10, 'Mitchel':11, 'SawyerW':12, 'Gilbert':13, 'NW Ames':14, 'Greens':15, 'Blmngtn':16, 'CollgCr':17, 'Crawfor':18,\
                           'ClearCr':19, 'Somerst':20, 'Stonebr':21, 'Somerst':22, 'Timber':23, 'Veenker':24, 'NRidgHt':25, 'StoneBr':26,'NoRidge':27, 'HaydnLk':28})

# %%
# 8 Condition1 - Proximity to various conditions
clean_df.Condition1 = clean_df.Condition1.replace({'Norm':1,'Feedr':0,'Artery':0,'RRAn':0,'RRAe':0,'RRNn':0,'RRNe':0,'PosN':2,'PosA':2})

# 9 Condition2 - Proximity to various conditions (if more than one is present)
clean_df.Condition2 = clean_df.Condition2.replace({'Norm':1,'Feedr':0,'Artery':0,'RRAn':0,'RRAe':0,'RRNn':0,'RRNe':0,'PosN':2,'PosA':2})

# %%
# 10 BldgType
clean_df.BldgType = clean_df.BldgType.replace({'2fmCon':1,'Twnhs':2, 'Duplex':3, '1Fam':4, 'TwnhsE':5})

# %%
# 11 HouseStyle - CHANGE to binary 0 =ranch, 1 = colonial 
clean_df.HouseStyle = clean_df.HouseStyle.replace({'1.5Unf':0,'1.5Fin':0, 'SFoyer':1, 'SLvl':1, '1Story':0, '2.5Unf':1, '2Story':1, '2.5Fin':1})

# %%
# 20 BsmtSF_Fin 
clean_df["BsmtSF_Fin"] =  clean_df['BsmtFinSF1'] + clean_df['BsmtFinSF2']

# %%
# 22 CentralAir - changed to binary 

clean_df.CentralAir = clean_df.CentralAir.replace({"Yes": 1, "No": 0})

# %%
# 23 Electrical - to dumify 
clean_df['Electrical'] = pd.get_dummies(clean_df['Electrical'])

# %%
#25 Bathroom
clean_df['HalfBath2'] = clean_df['HalfBath'].fillna(0.0)*0.5
clean_df['BsmtFullBath2'] = clean_df['BsmtFullBath'].fillna(0.0)*.6 
clean_df['BsmtHalfBath2'] = clean_df['BsmtHalfBath'].fillna(0.0)*.2

clean_df['bathroom'] = clean_df['FullBath'] + clean_df['HalfBath2'] + clean_df['BsmtFullBath2'] + clean_df['BsmtHalfBath2']

# %%
# 30 GarageType

clean_df["GarageType"] = clean_df.GarageType.apply(lambda x: 0 if x == 'Attchd' else(1))

# %%
# 31 Garage Finish
clean_df.GarageFinish.fillna(0, inplace=True)
clean_df.GarageFinish = clean_df.GarageFinish.replace({'Unf':0,'Rfn':1, 'Fin':1})

# %%
#34 PorchTotSF
clean_df['GrPorchArea']=clean_df['OpenPorchSF']+clean_df['EnclosedPorch']+clean_df['3SsnPorch'] + clean_df['ScreenPorch']

# %%
# 35 HasPorch
clean_df['HasPorch']=clean_df.GrPorchArea.apply(lambda x: 1 if x>0 else(0))

# %%
# 36 HasDeck 
clean_df['HasDeck']=clean_df.WoodDeckSF.apply(lambda x: 1 if x>0 else(0))

# %%
# 37 HasPool
clean_df['Pool_YN']=clean_df.PoolArea.apply(lambda x: 1 if x>0 else(0))

# %%
# 38 Fence 
clean_df.Fence.fillna(0, inplace=True)
clean_df.Fence = clean_df.Fence.replace({'MnWw':1,'GdWo':2, 'MnPrv':3, 'GdPrv':4})

# %%
# 39 MoSold

# %%
# 40 HasGarage 
clean_df['GarageCars'] = clean_df.GarageCars.apply(lambda x: 1 if x>0 else(0))

# %%
# 41 HasFinBsmt
clean_df['BsmtSF_Fin'] = clean_df.BsmtSF_Fin.apply(lambda x: 1 if x>0 else(0))

# %%
# 42 BeenRemod
clean_df['BeenRemod'] = np.where(clean_df.YearRemodAdd != clean_df.YearBuilt, 1, 0)

# %%
# 43 shed
clean_df['Shed'] = clean_df.MiscFeature=='Shed'
clean_df.Shed = clean_df.Shed.astype(int)

# 44 Gar2
clean_df['Gar2'] = clean_df.MiscFeature=='Gar2'
clean_df.Gar2 = clean_df.Gar2.astype(int)

clean_df.drop(columns='MiscFeature', inplace=True)

# %%
# 45 Log-Lat
real_housing["address_lat_log"] = address_lat_log
college_dist

# %%
# 46 Distance to Highschool
real_housing['highschool_dist'] = highschool_dist

# %%
# 47 Distance to College
real_housing['college_dist'] =

# %%
# 48 Latitude

# 49 Longitude

# separate tuple to two columns
dataset[['latitude', 'longitude']] = pd.DataFrame(dataset["address_lat_log"].tolist(), index = dataset.index)

# %% [markdown]
# # Dropped columns

# %%
clean_df.drop(columns='GarageYrBlt', inplace=True)

# %%
#drop PoolQC 
clean_df.PoolQC.fillna(0, inplace=True)
clean_df.PoolQC = clean_df.PoolQC.replace({"Fa":1, "TA":2, "Gd":3,"Ex":4})

# %%
# Replace with Curl Appeal

#clean_df.Alley = clean_df.Alley.replace({'Grvl':1,'Pave':2,'None':3})

# %%
# # 'OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch'
# clean_df.drop(columns = ['OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch'],inplace=True)

# #drop Bathroom ['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath']
# clean_df.drop(columns = ['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath'],inplace=True)

# #drop Basement columns ['BsmtFinSF1', 'BsmtFinSF2']
# clean_df.drop(columns = ['BsmtFinSF1', 'BsmtFinSF2'],inplace=True)

# # PoolArea
# clean_df.drop(columns='PoolArea',inplace=True)

#dropping extra columns
clean_df.drop(columns=["MSSubClass", "Street", "Alley", "LotShape", "LandContour", "LotConfig", "LandSlope", "RoofStyle", "RoofMatl", \
"Exterior1st", "Exterior2nd", "MasVnrType", "MasVnrArea", "YearRemodAdd", "Foundation", "BsmtExposure", "BsmtFinType1", \
"BsmtFinSF1", "BsmtFinType2", "BsmtFinSF2", "BsmtUnfSF", "Heating", "1stFlrSF", "2ndFlrSF", "LowQualFinSF", "BsmtFullBath", \
"BsmtHalfBath", "FullBath", "HalfBath", "KitchenAbvGr", "KitchenQual", "TotRmsAbvGrd", "GarageYrBlt", "GarageCond", \
"PavedDrive", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch", "PoolArea", "PoolQC", "MiscFeature", \
"MiscVal", "SaleType", "SaleCondition", "YrSold"],inplace=True)

# %% [markdown]
# # Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

# %%
X = clean_df.drop(labels=['SalePrice', 'SalePriceLog'], axis=1)
y = clean_df['SalePriceLog']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)
X_train.shape, X_test.shape
# Out:
# ((1799, 190), (771, 190))

# %%
scaler = StandardScaler()
scaler.fit(X_train.fillna(0))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
sel_ = SelectFromModel(LogisticRegression(C=1, penalty='l1'))
sel_.fit(scaler.transform(X_train.fillna(0)), y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# SelectFromModel(estimator=LogisticRegression(C=1, class_weight=None, dual=False,
#                                              fit_intercept=True,
#                                              intercept_scaling=1, l1_ratio=None,
#                                              max_iter=100, multi_class='warn',
#                                              n_jobs=None, penalty='l1',
#                                              random_state=None, solver='warn',
#                                              tol=0.0001, verbose=0,
#                                              warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
selected_feat = X_train.columns[(sel_.get_support())]
print('total features: {}'.format((X_train.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(
      np.sum(sel_.estimator_.coef_ == 0)))
# Out:
# total features: 190
# selected features: 94
# features with coefficients shrank to zero: 96

# %%
np.sum(sel_.estimator_.coef_ == 0)
# Out:
# 96

# %%
removed_feats = X_train.columns[(sel_.estimator_.coef_ == 0).ravel().tolist()]
removed_feats
# Out:
# Index(['PID', 'LotFrontage', 'Utilities', 'ExterQual', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', '2ndFlrSF', 'BedroomAbvGr',
#        'KitchenAbvGr', 'KitchenQual', 'Fireplaces', 'GarageCars', 'GarageArea',
#        'GarageQual', 'PoolQC', 'MiscVal', 'Gar2', 'Pool_YN',
#        'MSZoning_A (agr)', 'MSZoning_C (all)', 'MSZoning_FV',
#        'MSZoning_I (all)', 'MSZoning_RH', 'Street_Grvl', 'Street_Pave',
#        'LotShape_Reg', 'LandContour_HLS', 'LandContour_Low',
#        'LotConfig_Corner', 'LotConfig_CulDSac', 'LotConfig_FR2',
#        'LotConfig_FR3', 'LotConfig_Inside', 'LandSlope_Mod', 'LandSlope_Sev',
#        'RoofStyle_Flat', 'RoofStyle_Gable', 'RoofStyle_Hip',
#        'RoofStyle_Mansard', 'RoofStyle_Shed', 'RoofMatl_CompShg',
#        'RoofMatl_Membran', 'RoofMatl_Metal', 'RoofMatl_Roll',
#        'RoofMatl_Tar&Grv', 'RoofMatl_WdShake', 'RoofMatl_WdShngl',
#        'Exterior1st_AsphShn', 'Exterior1st_BrkComm', 'Exterior1st_BrkFace',
#        'Exterior1st_CBlock', 'Exterior1st_ImStucc', 'Exterior1st_PreCast',
#        'Exterior1st_VinylSd', 'Exterior2nd_AsbShng', 'Exterior2nd_AsphShn',
#        'Exterior2nd_CBlock', 'Exterior2nd_ImStucc', 'Exterior2nd_MetalSd',
#        'Exterior2nd_Plywood', 'Exterior2nd_PreCast', 'Exterior2nd_VinylSd',
#        'MasVnrType_0', 'MasVnrType_None', 'MasVnrType_Stone',
#        'Foundation_PConc', 'Foundation_Wood', 'BsmtExposure_4',
#        'Heating_Floor', 'Heating_GasW', 'Heating_OthW', 'Heating_Wall',
#        'CentralAir_N', 'CentralAir_Y', 'Electrical_0', 'Electrical_FuseF',
#        'Functional_Maj1', 'Functional_Sal', 'Functional_Typ', 'GarageType_0',
#        'GarageType_2Types', 'GarageType_Attchd', 'GarageType_Basment',
#        'GarageType_BuiltIn', 'GarageFinish_1', 'PavedDrive_N', 'SaleType_CWD',
#        'SaleType_Con', 'SaleType_ConLD', 'SaleType_New', 'SaleType_VWD',
#        'SaleType_WD ', 'SaleCondition_Normal', 'SaleCondition_Partial'],
#       dtype='object')

# %%
X_train_selected = sel_.transform(X_train.fillna(0))
X_test_selected = sel_.transform(X_test.fillna(0))

# %%
from sklearn.linear_model import LinearRegression 

ols = LinearRegression()
ols.fit(X_train_selected, y_train)
print("R^2 for train set: %f" %ols.score(X_train_selected, y_train))

print('-'*50)

print("R^2 for test  set: %f" %ols.score(X_test_selected, y_test))
# Out:
# R^2 for train set: 0.489891
# --------------------------------------------------
# R^2 for test  set: 0.302988

# %%
X2 = clean_df.drop(columns = ['SalePrice','SalePriceLog'])

# %%
y2 = clean_df[['SalePriceLog']]
y2
# Out:
#      SalePriceLog
# 1               5
# 2               5
# 3               5
# 4               5
# 5               5
# ..            ...
# 759             5
# 760             5
# 761             5
# 762             5
# 763             5
#
# [2570 rows x 1 columns]

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X2,y2)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X2.columns)
feat_importances.nlargest(30).plot(kind='barh', figsize=(6,8))
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# [9.27317529e-03 3.72591148e-02 1.08910004e-02 9.38090207e-03
#  1.10571876e-02 5.94346288e-03 2.82797339e-04 2.14892054e-02
#  3.01214341e-03 8.18391735e-04 5.31919762e-03 7.67579404e-03
#  3.76418325e-02 1.90738421e-02 9.95628988e-03 2.39722465e-02
#  3.59163369e-03 4.94181024e-03 5.14141620e-03 1.50155816e-02
#  2.49940822e-02 8.65066596e-03 1.18017918e-02 4.19143345e-03
#  5.34683662e-03 9.00592721e-03 2.59271630e-02 1.08769595e-02
#  2.27249980e-02 1.40727545e-02 4.63248974e-04 9.14047874e-03
#  3.76347142e-03 1.03248772e-02 3.50223580e-03 1.60643855e-02
#  1.50303993e-03 6.68481168e-03 2.05021297e-02 9.86700972e-03
#  1.25550181e-02 2.48511689e-02 7.89793375e-03 5.16689021e-03
#  3.17289212e-02 5.73368908e-03 0.00000000e+00 5.24037469e-03
#  1.94245317e-03 7.19924880e-03 7.86427066e-03 1.22336034e-03
#  7.74764022e-04 1.20102855e-02 0.00000000e+00 5.52056895e-04
#  4.75956463e-03 9.81352405e-04 0.00000000e+00 1.07905130e-03
#  2.02728703e-02 6.63183192e-03 9.72190665e-04 1.91086002e-03
#  4.99488124e-03 2.16811293e-04 3.77063118e-04 2.91654206e-03
#  2.65403182e-03 2.16305717e-03 9.15487071e-04 2.07819788e-03
#  4.25016594e-03 2.82797339e-04 9.34023171e-04 0.00000000e+00
#  3.01194303e-03 2.60935648e-03 3.21938224e-03 0.00000000e+00
#  0.00000000e+00 2.49274335e-03 2.73424255e-03 2.58700913e-03
#  0.00000000e+00 0.00000000e+00 1.00999050e-05 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 4.61902320e-04 0.00000000e+00
#  0.00000000e+00 2.38910553e-03 4.38698436e-04 0.00000000e+00
#  1.39946543e-03 0.00000000e+00 1.17257780e-02 9.80442402e-04
#  0.00000000e+00 3.88784836e-03 7.90633993e-04 0.00000000e+00
#  1.78703821e-03 4.82709313e-03 2.84082553e-03 1.14051794e-03
#  2.58405768e-03 0.00000000e+00 0.00000000e+00 2.06212031e-04
#  0.00000000e+00 6.23425235e-03 2.96774570e-03 1.95988957e-03
#  3.98814215e-03 1.09421757e-03 0.00000000e+00 1.74719157e-03
#  3.97113214e-03 4.11101846e-03 3.25678616e-03 1.47223731e-03
#  0.00000000e+00 0.00000000e+00 1.47486107e-03 4.48190335e-03
#  1.19988500e-03 7.70895847e-03 7.98134698e-03 9.03066081e-03
#  2.11907163e-03 2.74227723e-04 0.00000000e+00 5.11447623e-03
#  1.10050789e-03 1.97061058e-03 3.13193534e-03 4.79217916e-03
#  0.00000000e+00 1.73340611e-03 2.09628195e-03 3.50139325e-03
#  5.03556515e-04 2.37827916e-03 4.33141132e-02 3.38908125e-02
#  0.00000000e+00 5.87397074e-03 4.02379821e-03 1.46264310e-03
#  9.38582540e-03 1.31737891e-04 2.82797339e-04 1.44324057e-03
#  2.95119578e-03 8.01663101e-04 1.07089985e-03 2.12524447e-03
#  7.38907763e-03 0.00000000e+00 8.16124122e-03 7.54126237e-05
#  2.53177167e-04 1.95405929e-03 5.24125219e-03 2.61005580e-02
#  3.95711874e-03 4.09085097e-03 1.27182918e-03 1.20422499e-02
#  2.86677143e-03 8.58240034e-03 2.46789475e-03 0.00000000e+00
#  0.00000000e+00 1.49127100e-03 4.71328898e-04 1.46470853e-03
#  1.31972091e-05 3.69308805e-03 0.00000000e+00 2.64073416e-03
#  4.45053498e-03 0.00000000e+00 0.00000000e+00 1.76105382e-03
#  5.00515719e-03 0.00000000e+00]

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(X2,y2,test_size=0.25)

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
lasso = Lasso()
ridge = Ridge()

# %%
ss.fit(Xtrain)
Xs_train = ss.transform(Xtrain)

# %%
params_lasso = [{'alpha':[1e-4, 1e-2, 0.1, 1, 2, 20]}]
params_ridge = [{'alpha':[1e-4, 1e-2, 0.1, 1, 2, 10]}]

# %%
from sklearn.model_selection import KFold

# %%
from sklearn.model_selection import GridSearchCV, KFold

kf5 = KFold(n_splits=5, shuffle=True)

grid_lasso = GridSearchCV(estimator=lasso, param_grid=params_lasso, cv=kf5)
grid_ridge = GridSearchCV(estimator=ridge, param_grid=params_ridge, cv=kf5)

grid_lasso.fit(Xs_train, ytrain)
grid_ridge.fit(Xs_train, ytrain)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              error_score='raise-deprecating',
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='warn', n_jobs=None,
#              param_grid=[{'alpha': [0.0001, 0.01, 0.1, 1, 2, 10]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
grid_lasso.best_score_
# Out:
# 0.37049407441235976

# %%
grid_ridge.best_score_
# Out:
# 0.3533521711968728

# %% [markdown]
# # Tree Based Models
#
# ## Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
gbm = GradientBoostingRegressor()
gbm.set_params(n_estimators:1000, 
            learning_rate:.3,
            max_depth:2,
            min_samples_leaf:3)
gbm.fit(X_train,Y_train)
print('-'*50)
print("The train set R^2 is %.3f" %(gbm.score(X_train, Y_train)))
print("The test set R^2 is %.3f" %(gbm.score(X_test,Y_test)))

# %%
param_grid={'n_estimators':[1000], 
            'learning_rate': [.3,.2,0.1],
            'max_depth':[1,2,3],
            'min_samples_leaf':[3]
           }

grid_search = GridSearchCV(estimator= gbm, param_grid= param_grid)
grid_search.fit(X_train,Y_train)

# %%
print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)

# %%
gbm.get_params

# %%
sorted(zip(X.columns, gbm.feature_importances_), key=lambda t:t[1], reverse=True)
